# %% [markdown]
# # NLTK

# %% [markdown]
# NLTK stands for Natural Language Toolkit. It is a Python library used for working with human language data (text). NLTK provides easy-to-use interfaces to over 50 corpora and lexical resources, along with a wide range of text-processing libraries for classification, tokenization, stemming, tagging, parsing, and more.

# %% [markdown]
# 🔧 What NLTK Is Used For:
#
# 1. Teaching and learning natural language processing
#
# 2. Building prototypes or small-scale NLP projects
#
# 3. Exploring and experimenting with text data

# %% [markdown]
# ![image.png](attachment:8b59c40f-ed3d-41cf-b596-a46b73066844.png)

# %% [markdown]
# ![image.png](attachment:75868bd4-8bf5-41d7-a87a-61c84da720e8.png)

# %%
# !pip install NLTK

# %%
import nltk

# Download tokenizer data
# nltk.download() 

from nltk.tokenize import sent_tokenize, word_tokenize

# Process a text

Text = "Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi"

# Sentence tokenize

Sentence = sent_tokenize(Text)
print('\n Sentence :',Sentence)

# Word tokenize

Word = word_tokenize(Text)
print('\n Word :',Word)
# Out:
#  Sentence : ['Dr.', 'Strange loves pav bhaji of mumbai.', 'Hulk loves chat of delhi']
#
#  Word : ['Dr', '.', 'Strange', 'loves', 'pav', 'bhaji', 'of', 'mumbai', '.', 'Hulk', 'loves', 'chat', 'of', 'delhi']

# %% [markdown]
# # SPACY

# %% [markdown]
# spaCy is a fast, modern, and industrial-strength Natural Language Processing (NLP) library for Python. It's designed specifically for production use cases, with a focus on performance, efficiency, and ease of use.

# %% [markdown]
# ![image.png](attachment:c79b698e-58b6-4e4a-9724-6021d2ff7967.png)

# %% [markdown]
# ![image.png](attachment:a7e0d647-5145-4f1c-b06b-9f8533da1862.png)

# %% [markdown]
# ![image.png](attachment:9aa47f6d-e0cb-408b-b042-c4c75e1fb40a.png)

# %%
# !pip install spacy

# %%
import spacy

# Load English language model

NLP = spacy.load("en_core_web_sm")

# Process a text

Doc = NLP("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")

# To print each sentence from the document

for sentence in Doc.sents:
    print('sentence :', sentence)

# To print each word from the sentence

for sentence in Doc.sents:
    for word in sentence:
        print('\nWord :',word)
# Out:
# sentence : Dr. Strange loves pav bhaji of mumbai.
# sentence : Hulk loves chat of delhi
#
# Word : Dr.
#
# Word : Strange
#
# Word : loves
#
# Word : pav
#
# Word : bhaji
#
# Word : of
#
# Word : mumbai
#
# Word : .
#
# Word : Hulk
#
# Word : loves
#
# Word : chat
#
# Word : of
#
# Word : delhi
